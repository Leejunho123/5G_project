# %% [markdown]
# ## 23 패키지로 정리

# %% [markdown]
# + 모듈
#   - 모듈은 파이썬 파일. 다른 파이썬 프로그램에서 임포트하여 사용하는 것을 가정하고 만들어진 파이썬 파일
# + 패키지
#   - 패키지는 여러 모듈을 묶은 것입니다. 패키지를 만들려먼 먼저 디렉터리를 만들고 그 안에 모듈(파이썬 파일)을 추가합니다.
# + 라이브러리
#   - 라이브러리는 여러 패키지를 묶은 것. 하나 이상의 디렉터리로 구성. 때로는 패키지를 가리켜 라이브러리라고 부르기도 합니다.

# %% [markdown]
# ### 23.1 파일 구성
# + 공용 디렉터리 하나 생성

# %% [markdown]
# ### 23.2 코어 클래스로 옮기기
# + step22.py 코드를 dezero/core_simple.py라는 코어 파일로 옮기는 것. core를 부이는 이유는 지금까지 구현한 기능이 DeZero의 핵심기능이라고 보기 때문.
# + 최종 형태인 core.py로 교체할 계획이기 때문에 당장은 core_simple.py로 시작

# %% [markdown]
# ### 23.3 연산자 오버로드

# %%
# !git clone https://github.com/Leejunho123/5G_project.git
# Out:
# Cloning into '5G_project'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 11066 (delta 20), reused 32 (delta 14), pack-reused 11028
# Receiving objects: 100% (11066/11066), 245.88 MiB | 29.18 MiB/s, done.
# Resolving deltas: 100% (2558/2558), done.
# Checking out files: 100% (228/228), done.

# %%
# %cd 5G_project/DeepLearning/
# Out:
# /content/5G_project/DeepLearning

# %%
import numpy as np
from dezero.core_simple import Variable
from dezero.core_simple import Function
from dezero.core_simple import using_config
from dezero.core_simple import no_grad
from dezero.core_simple import as_array
from dezero.core_simple import as_variable
from dezero.core_simple import setup_variable

setup_variable()

# %%
x = Variable(np.array(1.0))
print(x)
# Out:
# variable(1.0)

# %% [markdown]
# ### 23.5 dezero 임포트하기

# %%
if '__file__' in globals():
  import os, sys
  sys.path.append(os.path.join(os.path.dirname(__file__),'..'))

import numpy as np
from dezero import Variable

# %%
x = Variable(np.array(1.0))
y = (x + 3) ** 2
y.backward()

print(y)
print(x.grad)
# Out:
# variable(16.0)
# 8.0
