# %% [markdown]
# ## 30 고차 미분

# %% [markdown]
# + 2차, 3차 미분 영역 확장

# %% [markdown]
# ### 30.1 확인 1 : Variable 인스턴트 변수
# + Variable 의 data, grad가 ndarray 를 참조하는 지 구분한다.

# %%
class Variable:
  def __init__(self, data, name=None):

# %% [markdown]
# ### 30.2 확인 2 : Function 클래스
# + data 및 forward만 적용 되고 Variable과 Function의 연결을 만들어줌

# %% [markdown]
# ### 30.3 확인 3 : Variable의 클래스 역전파
# + 역전파 시 grad에도 ndarray 참조.
