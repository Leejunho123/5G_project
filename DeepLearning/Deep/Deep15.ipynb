# %% [markdown]
# ## 15 복잡한 계산 그래프 (이론 편)

# %% [markdown]
# ### 15.1 역전파의 올바른 순서

# %% [markdown]
# ### 15.2 현재의 DeZero

# %% [markdown]
# + 실제 creator 를 funcs에 append하고 pop으로 꺼내기 때문에 한쪽이 다 끝난 뒤에야 다른 한쪽을 실행 - 오류

# %% [markdown]
# ### 15.3 함수 우선순위

# %% [markdown]
# + 각 층을 기록하여 우선순위를 주면 된다. 실제로 각각이 몇 층인지는 알고 있다.
