# %% [markdown]
# ## 10 테스트

# %% [markdown]
# ### colab 접속

# %%
if __name__ == '__main__':
  # !pip install import_ipynb
  from google.colab import drive
  drive.mount('/content/drive')
  # %cd /content/drive/MyDrive/밑바닥부터 시작하는 딥러닝3
# Out:
# ...
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=0838c1f22d9314f63499df19f763dca5b402d4dea253061a3dc07d95c58f8f0a
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# ...
# Mounted at /content/drive
# /content/drive/MyDrive/밑바닥부터 시작하는 딥러닝3

# %%
import numpy as np
import import_ipynb
from Deep09 import Variable, square, exp

# %% [markdown]
# ### 10.1 파이썬 단위 테스트

# %%
import unittest

class SquareTest(unittest.TestCase):
  def test_forward(self):
    x = Variable(np.array(2.0))
    y = square(x)
    expected = np.array(4.0)
    self.assertEqual(y.data, expected)

# %% [markdown]
# #### py 이므로 py생성

# %% [markdown]
# 10.2에서 테스트를 하나 추가하기 때문에 Ran2가 뜰 것입니다.

# %%
if __name__ == '__main__':
  # !python -m unittest deep10.py
# Out:
# importing Jupyter notebook from Deep09.ipynb
# importing Jupyter notebook from Deep08.ipynb
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK

# %% [markdown]
# ### 10.2 square 함수의 역전파 테스트

# %%
class SquareTest(unittest.TestCase):
  def test_forward(self):
    x = Variable(np.array(2.0))
    y = square(x)
    expected = np.array(4.0)
    self.assertEqual(y.data, expected)

  def test_backward(self):
    x = Variable(np.array(3.0))
    y = square(x)
    y.backward()
    expected = np.array(6.0)
    self.assertEqual(x.grad, expected)

# %%
if __name__ == '__main__':
  # !python -m unittest deep10.py
# Out:
# importing Jupyter notebook from Deep09.ipynb
# importing Jupyter notebook from Deep08.ipynb
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.000s
#
# OK

# %% [markdown]
# ### 10.3 기울기 확인을 이용한 자동 테스트

# %%
def numerical_diff(f,x,eps=1e-4):
  x0 = Variable(x.data - eps)
  x1 = Variable(x.data + eps)
  y0 = f(x0)
  y1 = f(x1)
  return (y1.data - y0.data) / (2*eps)

class SquareTest(unittest.TestCase):
  def test_forward(self):
    x = Variable(np.array(2.0))
    y = square(x)
    expected = np.array(4.0)
    self.assertEqual(y.data, expected)

  def test_backward(self):
    x = Variable(np.array(3.0))
    y = square(x)
    y.backward()
    expected = np.array(6.0)
    self.assertEqual(x.grad, expected)

  def test_gradient_check(self):
    x = Variable(np.random.rand(1))
    y = square(x)
    y.backward()
    num_grad = numerical_diff(square,x)
    flg = np.allclose(x.grad,num_grad)
    self.assertTrue(flg)

# %% [markdown]
# #### np.allclose(a,b)
# + ndarray 인스턴스인 a, b 값이 가까운지 판정합니다. 가까운지의 정도는 np.allclose(a,b,rtol=1e-05, atol=1e-08) 과 같이 인수 rtol과 atol로 지정할 수 있습니다. 모든 요소가 다음 조건을 만족하면 True를 반환합니다.
# + |a - b| <= (atol + rtol *|b|)
# + 함수에 따라서 atol 과 rtol의 값을 미세하게 조장해야 할수도 있습니다.

# %%
if __name__ == '__main__':
  # !python -m unittest deep10.py
# Out:
# importing Jupyter notebook from Deep09.ipynb
# importing Jupyter notebook from Deep08.ipynb
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.001s
#
# OK

# %% [markdown]
# ### 10.4 테스트 정리
