# %% [markdown]
# ## 31 고차 미분 (이론 편)

# %% [markdown]
# ### 31.1 역전파 계산
# + 현재 미분 시 gy 또한 구해야하기 때문에 2차 미분이 실행 되고 있음
# + 목표는 미분 계산을 계산 그래프로 만드는 것. 역전파를 그래프로 만들기

# %% [markdown]
# ### 31.2 역전파로 계산 그래프 만들기
# + 역전파 시 grad를 Variable 인스턴스를 참조하도록 변경
