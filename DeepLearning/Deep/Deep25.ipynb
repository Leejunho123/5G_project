# %% [markdown]
# ## 25 계산 그래프 시각화 (1)

# %% [markdown]
# ### 25.1 Graphviz 설치하기
# + 그래프 시각화 도구

# %%
# !apt install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# !dot -V
# Out:
# dot - graphviz version 2.40.1 (20161225.0304)

# %% [markdown]
# + dot 사용법

# %% [markdown]
# ### 25.2 DOT 언어로 그래프 작성하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
  # %cd /content/drive/MyDrive/밑바닥부터 시작하는 딥러닝3/step25dot
# Out:
# /content/drive/MyDrive/밑바닥부터 시작하는 딥러닝3/step25dot

# %%
# !dot sample.dot -T png -o sample.png

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 25.3 노드에 속성 지정하기

# %%
# !dot sample2.dot -T png -o sample2.png

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !dot sample3.dot -T png -o sample3.png

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 25.4 노드 연결하기

# %%
# !dot sample4.dot -T png -o sample4.png

# %% [markdown]
# ![image.png](data:image/png;base64,...)
