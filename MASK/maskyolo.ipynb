# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -la "/content/drive/MyDrive/darknet"
# Out:
# total 28
# drwx------ 2 root root 4096 Dec 23 03:15 backup
# drwx------ 2 root root 4096 Dec 23 02:25 bin
# drwx------ 2 root root 4096 Dec 23 02:53 cfg
# drwx------ 2 root root 4096 Dec 23 03:20 cuDNN
# drwx------ 2 root root 4096 Dec 23 03:02 custom
# drwx------ 2 root root 4096 Dec 23 02:54 data
# drwx------ 2 root root 4096 Dec 23 02:34 weights

# %%
# !tar -xzvf /content/drive/MyDrive/darknet/cuDNN/cudnn-10.1-linux-x64-v7.6.5.32.tgz -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h

# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.6.5
# cuda/lib64/libcudnn_static.a
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 6
# #define CUDNN_PATCHLEVEL 5
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# !ls -la /usr/local/cuda/include/cudnn.h
# Out:
# -r--r--r-- 1 root root 134857 Sep 26  2019 /usr/local/cuda/include/cudnn.h

# %% [markdown]
# 3. Load DarkNet

# %%
import os
if not os.path.exists('darknet'):
    os.makedirs('darknet')
# %cd darknet
# %ls
# Out:
# /content/darknet

# %%
# !ls -la '/content/drive/MyDrive/darknet/bin/darknet'

# !cp /content/drive/MyDrive/darknet/bin/darknet ./darknet

# !chmod +x ./darknet
# Out:
# -rw------- 1 root root 3213624 Dec 23 02:26 /content/drive/MyDrive/darknet/bin/darknet

# %%
# !cp -r "/content/drive/MyDrive/ColabNotebooks/MASK" .

# %%
# !cp -r "/content/drive/MyDrive/ColabNotebooks/MASK/backup" ./backup

# %%
# !cp -r '/content/drive/MyDrive/darknet/weights' .

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

      
def download(path):
  from google.colab import files
  files.download(path)

# %%
# !./darknet detector train MASK/custom_data.data MASK/custom-train-yolo.cfg weights/darknet53.conv.74 -dont_show
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
#  2806: 0.023568, 0.057855 avg loss, 0.001000 rate, 2.131117 seconds, 89792 images
# Loaded: 0.202031 seconds
#
#  2807: 0.018525, 0.053922 avg loss, 0.001000 rate, 2.133165 seconds, 89824 images
# Loaded: 0.380136 seconds
#  Very small path to the image:
#
#  2808: 0.049251, 0.053455 avg loss, 0.001000 rate, 2.110413 seconds, 89856 images
# Loaded: 0.344823 seconds
#
#  2809: 0.040595, 0.052169 avg loss, 0.001000 rate, 2.142378 seconds, 89888 images
# Loaded: 0.326711 seconds
#
#  2810: 0.024714, 0.049424 avg loss, 0.001000 rate, 2.129875 seconds, 89920 images
# Resizing
# 352 x 352
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.838850 seconds
#  Very small path to the image:
#
#  2811: 0.074605, 0.051942 avg loss, 0.001000 rate, 1.945559 seconds, 89952 images
# Loaded: 0.373191 seconds
#  Very small path to the image:
#
#  2812: 0.039889, 0.050737 avg loss, 0.001000 rate, 1.881451 seconds, 89984 images
# Loaded: 0.457486 seconds
#
#  2813: 0.042336, 0.049897 avg loss, 0.001000 rate, 1.862126 seconds, 90016 images
# Loaded: 0.150672 seconds
#  Very small path to the image:
#
#  2814: 0.046526, 0.049559 avg loss, 0.001000 rate, 1.869941 seconds, 90048 images
# Loaded: 0.595558 seconds
#
#  2815: 0.069393, 0.051543 avg loss, 0.001000 rate, 1.879165 seconds, 90080 images
# Loaded: 0.758314 seconds
#  Very small path to the image:
#
#  2816: 0.090298, 0.055418 avg loss, 0.001000 rate, 1.886961 seconds, 90112 images
# Loaded: 0.988154 seconds
#  Very small path to the image:
#
#  2817: 0.072538, 0.057130 avg loss, 0.001000 rate, 1.881010 seconds, 90144 images
# Loaded: 0.873117 seconds
#  Very small path to the image:
#
#  2818: 0.130774, 0.064495 avg loss, 0.001000 rate, 1.853780 seconds, 90176 images
# Loaded: 0.423489 seconds
#
#  2819: 0.050884, 0.063134 avg loss, 0.001000 rate, 1.871391 seconds, 90208 images
# Loaded: 0.822002 seconds
#
#  2820: 0.046139, 0.061434 avg loss, 0.001000 rate, 1.866829 seconds, 90240 images
# Resizing
# 448 x 448
#  Very small path to the image:
#  try to allocate additional workspace_size = 59.01 MB
#  CUDA allocate done!
# Loaded: 0.610356 seconds
#  Very small path to the image:
#
#  2821: 0.035561, 0.058847 avg loss, 0.001000 rate, 2.771650 seconds, 90272 images
# Loaded: 0.000032 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2822: 0.040684, 0.057030 avg loss, 0.001000 rate, 2.835133 seconds, 90304 images
# Loaded: 0.000038 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2823: 0.050182, 0.056346 avg loss, 0.001000 rate, 2.831347 seconds, 90336 images
# Loaded: 0.000037 seconds
#  Very small path to the image:
#
#  2824: 0.031334, 0.053844 avg loss, 0.001000 rate, 2.823975 seconds, 90368 images
# Loaded: 0.000032 seconds
#  Very small path to the image:
#
#  2825: 0.021421, 0.050602 avg loss, 0.001000 rate, 2.825290 seconds, 90400 images
# Loaded: 0.159858 seconds
#  Very small path to the image:
#
#  2826: 0.031370, 0.048679 avg loss, 0.001000 rate, 2.757234 seconds, 90432 images
# Loaded: 0.000052 seconds
#
#  2827: 0.031667, 0.046978 avg loss, 0.001000 rate, 2.818507 seconds, 90464 images
# Loaded: 0.000037 seconds
#
#  2828: 0.042175, 0.046497 avg loss, 0.001000 rate, 2.846205 seconds, 90496 images
# Loaded: 0.000043 seconds
#
#  2829: 0.028554, 0.044703 avg loss, 0.001000 rate, 2.852176 seconds, 90528 images
# Loaded: 0.248725 seconds
#  Very small path to the image:
#
#  2830: 0.028260, 0.043059 avg loss, 0.001000 rate, 2.747266 seconds, 90560 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 97.55 MB
#  CUDA allocate done!
# Loaded: 0.314086 seconds
#
#  2831: 0.054198, 0.044173 avg loss, 0.001000 rate, 4.550256 seconds, 90592 images
# Loaded: 0.000044 seconds
#
#  2832: 0.051578, 0.044913 avg loss, 0.001000 rate, 4.658441 seconds, 90624 images
# Loaded: 0.000039 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2833: 0.039990, 0.044421 avg loss, 0.001000 rate, 4.659022 seconds, 90656 images
# Loaded: 0.000034 seconds
#
#  2834: 0.042174, 0.044196 avg loss, 0.001000 rate, 4.670248 seconds, 90688 images
# Loaded: 0.000031 seconds
#  Very small path to the image:
#
#  2835: 0.048561, 0.044633 avg loss, 0.001000 rate, 4.676405 seconds, 90720 images
# Loaded: 0.000049 seconds
#  Very small path to the image:
#
#  2836: 0.022756, 0.042445 avg loss, 0.001000 rate, 4.660785 seconds, 90752 images
# Loaded: 0.000033 seconds
#
#  2837: 0.048888, 0.043089 avg loss, 0.001000 rate, 4.663553 seconds, 90784 images
# Loaded: 0.000032 seconds
#
#  2838: 0.029711, 0.041751 avg loss, 0.001000 rate, 4.673049 seconds, 90816 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#
#  2839: 0.041974, 0.041774 avg loss, 0.001000 rate, 4.684953 seconds, 90848 images
# Loaded: 0.000036 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2840: 0.039057, 0.041502 avg loss, 0.001000 rate, 4.664817 seconds, 90880 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 97.55 MB
#  CUDA allocate done!
# Loaded: 1.977891 seconds
#  Very small path to the image:
#
#  2841: 0.026542, 0.040006 avg loss, 0.001000 rate, 4.532951 seconds, 90912 images
# Loaded: 0.000057 seconds
#  Very small path to the image:
#
#  2842: 0.052488, 0.041254 avg loss, 0.001000 rate, 4.641025 seconds, 90944 images
# Loaded: 0.000031 seconds
#
#  2843: 0.045713, 0.041700 avg loss, 0.001000 rate, 4.653966 seconds, 90976 images
# Loaded: 0.000041 seconds
#
#  2844: 0.022737, 0.039804 avg loss, 0.001000 rate, 4.689364 seconds, 91008 images
# Loaded: 0.000035 seconds
#
#  2845: 0.037972, 0.039621 avg loss, 0.001000 rate, 4.673358 seconds, 91040 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2846: 0.041717, 0.039830 avg loss, 0.001000 rate, 4.655073 seconds, 91072 images
# Loaded: 0.000057 seconds
#  Very small path to the image:
#
#  2847: 0.025931, 0.038440 avg loss, 0.001000 rate, 4.678854 seconds, 91104 images
# Loaded: 0.000038 seconds
#  Very small path to the image:
#
#  2848: 0.055411, 0.040137 avg loss, 0.001000 rate, 4.676312 seconds, 91136 images
# Loaded: 0.000037 seconds
#
#  2849: 0.033625, 0.039486 avg loss, 0.001000 rate, 4.681343 seconds, 91168 images
# Loaded: 0.000042 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2850: 0.040182, 0.039556 avg loss, 0.001000 rate, 4.667338 seconds, 91200 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 2.006997 seconds
#  Very small path to the image:
#
#  2851: 0.027363, 0.038336 avg loss, 0.001000 rate, 2.566562 seconds, 91232 images
# Loaded: 0.000045 seconds
#  Very small path to the image:
#
#  2852: 0.032024, 0.037705 avg loss, 0.001000 rate, 2.561115 seconds, 91264 images
# Loaded: 0.000037 seconds
#
#  2853: 0.035192, 0.037454 avg loss, 0.001000 rate, 2.573460 seconds, 91296 images
# Loaded: 0.000030 seconds
#
#  2854: 0.033731, 0.037082 avg loss, 0.001000 rate, 2.590576 seconds, 91328 images
# Loaded: 0.189726 seconds
#
#  2855: 0.049892, 0.038363 avg loss, 0.001000 rate, 2.473642 seconds, 91360 images
# Loaded: 0.106477 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2856: 0.023547, 0.036881 avg loss, 0.001000 rate, 2.464565 seconds, 91392 images
# Loaded: 0.015280 seconds
#  Very small path to the image:
#
#  2857: 0.051636, 0.038357 avg loss, 0.001000 rate, 2.550127 seconds, 91424 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#
#  2858: 0.022532, 0.036774 avg loss, 0.001000 rate, 2.562567 seconds, 91456 images
# Loaded: 0.000036 seconds
#
#  2859: 0.024419, 0.035539 avg loss, 0.001000 rate, 2.575114 seconds, 91488 images
# Loaded: 0.017001 seconds
#  Very small path to the image:
#
#  2860: 0.031434, 0.035128 avg loss, 0.001000 rate, 2.566477 seconds, 91520 images
# Resizing
# 448 x 448
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 59.01 MB
#  CUDA allocate done!
# Loaded: 1.581617 seconds
#  Very small path to the image:
#
#  2861: 0.041741, 0.035789 avg loss, 0.001000 rate, 2.777855 seconds, 91552 images
# Loaded: 0.000036 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  2862: 0.026178, 0.034828 avg loss, 0.001000 rate, 2.824055 seconds, 91584 images
# Loaded: 0.028140 seconds
#  Very small path to the image:
#
#  2863: 0.058311, 0.037176 avg loss, 0.001000 rate, 2.791878 seconds, 91616 images
# Loaded: 0.000060 seconds
#
#  2864: 0.025408, 0.036000 avg loss, 0.001000 rate, 2.825845 seconds, 91648 images
# Loaded: 0.000044 seconds
#
#  2865: 0.038696, 0.036269 avg loss, 0.001000 rate, 2.842445 seconds, 91680 images
# Loaded: 0.382475 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2866: 0.035698, 0.036212 avg loss, 0.001000 rate, 2.723588 seconds, 91712 images
# Loaded: 0.000051 seconds
#
#  2867: 0.016361, 0.034227 avg loss, 0.001000 rate, 2.841073 seconds, 91744 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#
#  2868: 0.029946, 0.033799 avg loss, 0.001000 rate, 2.841056 seconds, 91776 images
# Loaded: 0.089123 seconds
#
#  2869: 0.021444, 0.032563 avg loss, 0.001000 rate, 2.722636 seconds, 91808 images
# Loaded: 0.000048 seconds
#
#  2870: 0.031078, 0.032415 avg loss, 0.001000 rate, 2.827830 seconds, 91840 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.112368 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2871: 0.037625, 0.032936 avg loss, 0.001000 rate, 2.197179 seconds, 91872 images
# Loaded: 0.505128 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2872: 0.032171, 0.032859 avg loss, 0.001000 rate, 2.099979 seconds, 91904 images
# Loaded: 0.147401 seconds
#
#  2873: 0.025414, 0.032115 avg loss, 0.001000 rate, 2.094006 seconds, 91936 images
# Loaded: 0.324463 seconds
#
#  2874: 0.025817, 0.031485 avg loss, 0.001000 rate, 2.105257 seconds, 91968 images
# Loaded: 0.000033 seconds
#
#  2875: 0.028314, 0.031168 avg loss, 0.001000 rate, 2.209198 seconds, 92000 images
# Loaded: 0.094549 seconds
#  Very small path to the image:
#
#  2876: 0.037413, 0.031793 avg loss, 0.001000 rate, 2.134883 seconds, 92032 images
# Loaded: 0.690786 seconds
#
#  2877: 0.052967, 0.033910 avg loss, 0.001000 rate, 2.119718 seconds, 92064 images
# Loaded: 0.452988 seconds
#
#  2878: 0.025176, 0.033037 avg loss, 0.001000 rate, 2.117012 seconds, 92096 images
# Loaded: 0.596830 seconds
#
#  2879: 0.027580, 0.032491 avg loss, 0.001000 rate, 2.096994 seconds, 92128 images
# Loaded: 0.000040 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2880: 0.051460, 0.034388 avg loss, 0.001000 rate, 2.181605 seconds, 92160 images
# Resizing
# 352 x 352
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 2.190977 seconds
#
#  2881: 0.051282, 0.036077 avg loss, 0.001000 rate, 1.973247 seconds, 92192 images
# Loaded: 0.576580 seconds
#  Very small path to the image:
#
#  2882: 0.030184, 0.035488 avg loss, 0.001000 rate, 1.859238 seconds, 92224 images
# Loaded: 0.913147 seconds
#  Very small path to the image:
#
#  2883: 0.063134, 0.038253 avg loss, 0.001000 rate, 1.868709 seconds, 92256 images
# Loaded: 0.558710 seconds
#
#  2884: 0.037284, 0.038156 avg loss, 0.001000 rate, 1.882520 seconds, 92288 images
# Loaded: 0.654582 seconds
#
#  2885: 0.048652, 0.039205 avg loss, 0.001000 rate, 1.851731 seconds, 92320 images
# Loaded: 0.016757 seconds
#
#  2886: 0.018397, 0.037124 avg loss, 0.001000 rate, 1.921064 seconds, 92352 images
# Loaded: 0.744137 seconds
#
#  2887: 0.061314, 0.039543 avg loss, 0.001000 rate, 1.872812 seconds, 92384 images
# Loaded: 0.271404 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  2888: 0.042978, 0.039887 avg loss, 0.001000 rate, 1.883578 seconds, 92416 images
# Loaded: 0.471918 seconds
#
#  2889: 0.071495, 0.043048 avg loss, 0.001000 rate, 1.895912 seconds, 92448 images
# Loaded: 0.479096 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2890: 0.042242, 0.042967 avg loss, 0.001000 rate, 1.895383 seconds, 92480 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 2.121634 seconds
#
#  2891: 0.107289, 0.049399 avg loss, 0.001000 rate, 1.942639 seconds, 92512 images
# Loaded: 0.622444 seconds
#  Very small path to the image:
#
#  2892: 0.035819, 0.048041 avg loss, 0.001000 rate, 1.875466 seconds, 92544 images
# Loaded: 0.378109 seconds
#
#  2893: 0.034361, 0.046673 avg loss, 0.001000 rate, 1.879982 seconds, 92576 images
# Loaded: 0.509825 seconds
#
#  2894: 0.053482, 0.047354 avg loss, 0.001000 rate, 1.861106 seconds, 92608 images
# Loaded: 0.856965 seconds
#
#  2895: 0.100200, 0.052639 avg loss, 0.001000 rate, 1.870505 seconds, 92640 images
# Loaded: 0.583787 seconds
#  Very small path to the image:
#
#  2896: 0.036894, 0.051064 avg loss, 0.001000 rate, 1.884584 seconds, 92672 images
# Loaded: 0.560952 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2897: 0.050031, 0.050961 avg loss, 0.001000 rate, 1.880095 seconds, 92704 images
# Loaded: 0.270363 seconds
#  Very small path to the image:
#
#  2898: 0.030994, 0.048964 avg loss, 0.001000 rate, 1.876006 seconds, 92736 images
# Loaded: 0.394683 seconds
#
#  2899: 0.044352, 0.048503 avg loss, 0.001000 rate, 1.871574 seconds, 92768 images
# Loaded: 0.314112 seconds
#  Very small path to the image:
#
#  2900: 0.022680, 0.045921 avg loss, 0.001000 rate, 1.890677 seconds, 92800 images
# Saving weights to backup/custom-train-yolo_last.weights
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 97.55 MB
#  CUDA allocate done!
# Loaded: 0.164936 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2901: 0.062875, 0.047616 avg loss, 0.001000 rate, 4.589518 seconds, 92832 images
# Loaded: 0.000035 seconds
#
#  2902: 0.046593, 0.047514 avg loss, 0.001000 rate, 4.688388 seconds, 92864 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#
#  2903: 0.043911, 0.047153 avg loss, 0.001000 rate, 4.679850 seconds, 92896 images
# Loaded: 0.000031 seconds
#
#  2904: 0.043896, 0.046828 avg loss, 0.001000 rate, 4.685347 seconds, 92928 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#
#  2905: 0.040971, 0.046242 avg loss, 0.001000 rate, 4.681513 seconds, 92960 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#
#  2906: 0.053168, 0.046935 avg loss, 0.001000 rate, 4.695975 seconds, 92992 images
# Loaded: 0.000050 seconds
#  Very small path to the image:
#
#  2907: 0.050974, 0.047339 avg loss, 0.001000 rate, 4.685041 seconds, 93024 images
# Loaded: 0.000046 seconds
#
#  2908: 0.028070, 0.045412 avg loss, 0.001000 rate, 4.663728 seconds, 93056 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2909: 0.041659, 0.045036 avg loss, 0.001000 rate, 4.661431 seconds, 93088 images
# Loaded: 0.000032 seconds
#
#  2910: 0.064475, 0.046980 avg loss, 0.001000 rate, 4.655812 seconds, 93120 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.391012 seconds
#  Very small path to the image:
#
#  2911: 0.043051, 0.046587 avg loss, 0.001000 rate, 1.941185 seconds, 93152 images
# Loaded: 0.807661 seconds
#  Very small path to the image:
#
#  2912: 0.066224, 0.048551 avg loss, 0.001000 rate, 1.858149 seconds, 93184 images
# Loaded: 0.813814 seconds
#  Very small path to the image:
#
#  2913: 0.032582, 0.046954 avg loss, 0.001000 rate, 1.855523 seconds, 93216 images
# Loaded: 0.526963 seconds
#  Very small path to the image:
#
#  2914: 0.061052, 0.048364 avg loss, 0.001000 rate, 1.859234 seconds, 93248 images
# Loaded: 0.966896 seconds
#  Very small path to the image:
#
#  2915: 0.069898, 0.050517 avg loss, 0.001000 rate, 1.849379 seconds, 93280 images
# Loaded: 0.400367 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  2916: 0.026607, 0.048126 avg loss, 0.001000 rate, 1.846467 seconds, 93312 images
# Loaded: 0.825183 seconds
#
#  2917: 0.035775, 0.046891 avg loss, 0.001000 rate, 1.865391 seconds, 93344 images
# Loaded: 0.846966 seconds
#
#  2918: 0.058311, 0.048033 avg loss, 0.001000 rate, 1.859299 seconds, 93376 images
# Loaded: 0.593304 seconds
#  Very small path to the image:
#
#  2919: 0.027148, 0.045945 avg loss, 0.001000 rate, 1.881498 seconds, 93408 images
# Loaded: 0.773036 seconds
#  Very small path to the image:
#
#  2920: 0.056056, 0.046956 avg loss, 0.001000 rate, 1.874001 seconds, 93440 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 97.55 MB
#  CUDA allocate done!
# Loaded: 0.400018 seconds
#
#  2921: 0.074696, 0.049730 avg loss, 0.001000 rate, 4.556631 seconds, 93472 images
# Loaded: 0.000033 seconds
#
#  2922: 0.076297, 0.052386 avg loss, 0.001000 rate, 4.662024 seconds, 93504 images
# Loaded: 0.000033 seconds
#
#  2923: 0.038202, 0.050968 avg loss, 0.001000 rate, 4.679204 seconds, 93536 images
# Loaded: 0.000038 seconds
#
#  2924: 0.069005, 0.052772 avg loss, 0.001000 rate, 4.733224 seconds, 93568 images
# Loaded: 0.000045 seconds
#  Very small path to the image:
#
#  2925: 0.046193, 0.052114 avg loss, 0.001000 rate, 4.724294 seconds, 93600 images
# Loaded: 0.000050 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2926: 0.043793, 0.051282 avg loss, 0.001000 rate, 4.717715 seconds, 93632 images
# Loaded: 0.000036 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2927: 0.033146, 0.049468 avg loss, 0.001000 rate, 4.710790 seconds, 93664 images
# Loaded: 0.000057 seconds
#
#  2928: 0.063815, 0.050903 avg loss, 0.001000 rate, 4.681130 seconds, 93696 images
# Loaded: 0.000030 seconds
#
#  2929: 0.043428, 0.050155 avg loss, 0.001000 rate, 4.691107 seconds, 93728 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  2930: 0.055783, 0.050718 avg loss, 0.001000 rate, 4.658183 seconds, 93760 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 59.01 MB
#  CUDA allocate done!
# Loaded: 1.796573 seconds
#
#  2931: 0.029586, 0.048605 avg loss, 0.001000 rate, 2.798479 seconds, 93792 images
# Loaded: 0.000048 seconds
#
#  2932: 0.038913, 0.047636 avg loss, 0.001000 rate, 2.808116 seconds, 93824 images
# Loaded: 0.000038 seconds
#
#  2933: 0.043829, 0.047255 avg loss, 0.001000 rate, 2.788630 seconds, 93856 images
# Loaded: 0.000043 seconds
#
#  2934: 0.047792, 0.047309 avg loss, 0.001000 rate, 2.813372 seconds, 93888 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#
#  2935: 0.039998, 0.046578 avg loss, 0.001000 rate, 2.807255 seconds, 93920 images
# Loaded: 0.134106 seconds
#
#  2936: 0.042674, 0.046187 avg loss, 0.001000 rate, 2.721456 seconds, 93952 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#
#  2937: 0.050777, 0.046646 avg loss, 0.001000 rate, 2.811706 seconds, 93984 images
# Loaded: 0.000039 seconds
#
#  2938: 0.031214, 0.045103 avg loss, 0.001000 rate, 2.811213 seconds, 94016 images
# Loaded: 0.241048 seconds
#  Very small path to the image:
#
#  2939: 0.053347, 0.045927 avg loss, 0.001000 rate, 2.747137 seconds, 94048 images
# Loaded: 0.517554 seconds
#
#  2940: 0.077863, 0.049121 avg loss, 0.001000 rate, 2.728159 seconds, 94080 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.400096 seconds
#
#  2941: 0.094866, 0.053696 avg loss, 0.001000 rate, 2.193034 seconds, 94112 images
# Loaded: 0.577076 seconds
#
#  2942: 0.051998, 0.053526 avg loss, 0.001000 rate, 2.112720 seconds, 94144 images
# Loaded: 0.786269 seconds
#
#  2943: 0.092331, 0.057406 avg loss, 0.001000 rate, 2.111091 seconds, 94176 images
# Loaded: 0.613253 seconds
#
#  2944: 0.042045, 0.055870 avg loss, 0.001000 rate, 2.094119 seconds, 94208 images
# Loaded: 0.000037 seconds
#
#  2945: 0.037255, 0.054009 avg loss, 0.001000 rate, 2.194250 seconds, 94240 images
# Loaded: 0.039155 seconds
#  Very small path to the image:
#
#  2946: 0.071189, 0.055727 avg loss, 0.001000 rate, 2.173538 seconds, 94272 images
# Loaded: 0.109803 seconds
#
#  2947: 0.052662, 0.055420 avg loss, 0.001000 rate, 2.111331 seconds, 94304 images
# Loaded: 0.585873 seconds
#
#  2948: 0.048550, 0.054733 avg loss, 0.001000 rate, 2.122311 seconds, 94336 images
# Loaded: 0.191596 seconds
#
#  2949: 0.041543, 0.053414 avg loss, 0.001000 rate, 2.135213 seconds, 94368 images
# Loaded: 0.874045 seconds
#
#  2950: 0.094924, 0.057565 avg loss, 0.001000 rate, 2.137310 seconds, 94400 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 97.55 MB
#  CUDA allocate done!
# Loaded: 0.222025 seconds
#
#  2951: 0.081995, 0.060008 avg loss, 0.001000 rate, 4.558589 seconds, 94432 images
# Loaded: 0.000040 seconds
#
#  2952: 0.048721, 0.058879 avg loss, 0.001000 rate, 4.671717 seconds, 94464 images
# Loaded: 0.000031 seconds
#
#  2953: 0.063458, 0.059337 avg loss, 0.001000 rate, 4.691948 seconds, 94496 images
# Loaded: 0.000074 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2954: 0.048100, 0.058213 avg loss, 0.001000 rate, 4.693577 seconds, 94528 images
# Loaded: 0.000039 seconds
#
#  2955: 0.052854, 0.057678 avg loss, 0.001000 rate, 4.706075 seconds, 94560 images
# Loaded: 0.000040 seconds
#
#  2956: 0.058599, 0.057770 avg loss, 0.001000 rate, 4.689046 seconds, 94592 images
# Loaded: 0.000036 seconds
#
#  2957: 0.051733, 0.057166 avg loss, 0.001000 rate, 4.672700 seconds, 94624 images
# Loaded: 0.000032 seconds
#  Very small path to the image:
#
#  2958: 0.036685, 0.055118 avg loss, 0.001000 rate, 4.675034 seconds, 94656 images
# Loaded: 0.000039 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2959: 0.023341, 0.051940 avg loss, 0.001000 rate, 4.675008 seconds, 94688 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  2960: 0.040089, 0.050755 avg loss, 0.001000 rate, 4.644301 seconds, 94720 images
# Resizing
# 608 x 608
#  Very small path to the image:
#  try to allocate additional workspace_size = 108.69 MB
#  CUDA allocate done!
# Loaded: 0.000041 seconds
#
#  2961: 0.046753, 0.050355 avg loss, 0.001000 rate, 4.936391 seconds, 94752 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#
#  2962: 0.053576, 0.050677 avg loss, 0.001000 rate, 5.049830 seconds, 94784 images
# Loaded: 0.000035 seconds
#
#  2963: 0.059544, 0.051564 avg loss, 0.001000 rate, 5.083852 seconds, 94816 images
# Loaded: 0.000033 seconds
#
#  2964: 0.049181, 0.051325 avg loss, 0.001000 rate, 5.094754 seconds, 94848 images
# Loaded: 0.000038 seconds
#  Very small path to the image:
#
#  2965: 0.053449, 0.051538 avg loss, 0.001000 rate, 5.102463 seconds, 94880 images
# Loaded: 0.000033 seconds
#
#  2966: 0.038326, 0.050217 avg loss, 0.001000 rate, 5.086257 seconds, 94912 images
# Loaded: 0.000031 seconds
#
#  2967: 0.036633, 0.048858 avg loss, 0.001000 rate, 5.083377 seconds, 94944 images
# Loaded: 0.000030 seconds
#
#  2968: 0.050783, 0.049051 avg loss, 0.001000 rate, 5.101120 seconds, 94976 images
# Loaded: 0.000031 seconds
#
#  2969: 0.060512, 0.050197 avg loss, 0.001000 rate, 5.093604 seconds, 95008 images
# Loaded: 0.000036 seconds
#
#  2970: 0.038849, 0.049062 avg loss, 0.001000 rate, 5.109734 seconds, 95040 images
# Resizing
# 448 x 448
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 59.01 MB
#  CUDA allocate done!
# Loaded: 1.161228 seconds
#  Very small path to the image:
#
#  2971: 0.048871, 0.049043 avg loss, 0.001000 rate, 2.802257 seconds, 95072 images
# Loaded: 0.125807 seconds
#
#  2972: 0.028508, 0.046989 avg loss, 0.001000 rate, 2.728317 seconds, 95104 images
# Loaded: 0.029579 seconds
#
#  2973: 0.042539, 0.046544 avg loss, 0.001000 rate, 2.808067 seconds, 95136 images
# Loaded: 0.134887 seconds
#  Very small path to the image:
#
#  2974: 0.028377, 0.044728 avg loss, 0.001000 rate, 2.716149 seconds, 95168 images
# Loaded: 0.000038 seconds
#  Very small path to the image:
#
#  2975: 0.023629, 0.042618 avg loss, 0.001000 rate, 2.816664 seconds, 95200 images
# Loaded: 0.135240 seconds
#
#  2976: 0.020059, 0.040362 avg loss, 0.001000 rate, 2.701064 seconds, 95232 images
# Loaded: 0.000039 seconds
#  Very small path to the image:
#
#  2977: 0.026387, 0.038964 avg loss, 0.001000 rate, 2.824394 seconds, 95264 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  2978: 0.049293, 0.039997 avg loss, 0.001000 rate, 2.817736 seconds, 95296 images
# Loaded: 0.224566 seconds
#  Very small path to the image:
#
#  2979: 0.062817, 0.042279 avg loss, 0.001000 rate, 2.733220 seconds, 95328 images
# Loaded: 0.186091 seconds
#
#  2980: 0.038817, 0.041933 avg loss, 0.001000 rate, 2.734000 seconds, 95360 images
# Resizing
# 416 x 416
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.898827 seconds
#
#  2981: 0.039066, 0.041646 avg loss, 0.001000 rate, 2.554350 seconds, 95392 images
# Loaded: 0.000060 seconds
#  Very small path to the image:
#
#  2982: 0.028178, 0.040299 avg loss, 0.001000 rate, 2.568880 seconds, 95424 images
# Loaded: 0.000038 seconds
#  Very small path to the image:
#
#  2983: 0.024277, 0.038697 avg loss, 0.001000 rate, 2.579638 seconds, 95456 images
# Loaded: 0.097409 seconds
#  Very small path to the image:
#
#  2984: 0.055611, 0.040389 avg loss, 0.001000 rate, 2.491038 seconds, 95488 images
# Loaded: 0.235527 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2985: 0.023372, 0.038687 avg loss, 0.001000 rate, 2.471907 seconds, 95520 images
# Loaded: 0.115839 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  2986: 0.045150, 0.039333 avg loss, 0.001000 rate, 2.479577 seconds, 95552 images
# Loaded: 0.069628 seconds
#
#  2987: 0.048293, 0.040229 avg loss, 0.001000 rate, 2.489190 seconds, 95584 images
# Loaded: 0.000036 seconds
#
#  2988: 0.028317, 0.039038 avg loss, 0.001000 rate, 2.592449 seconds, 95616 images
# Loaded: 0.168831 seconds
#
#  2989: 0.022550, 0.037389 avg loss, 0.001000 rate, 2.496565 seconds, 95648 images
# Loaded: 0.324964 seconds
#
#  2990: 0.018679, 0.035518 avg loss, 0.001000 rate, 2.473668 seconds, 95680 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.731326 seconds
#
#  2991: 0.029383, 0.034905 avg loss, 0.001000 rate, 2.178714 seconds, 95712 images
# Loaded: 0.098369 seconds
#
#  2992: 0.077774, 0.039192 avg loss, 0.001000 rate, 2.106978 seconds, 95744 images
# Loaded: 0.263073 seconds
#  Very small path to the image:
#
#  2993: 0.033312, 0.038604 avg loss, 0.001000 rate, 2.114053 seconds, 95776 images
# Loaded: 0.533763 seconds
#
#  2994: 0.038222, 0.038565 avg loss, 0.001000 rate, 2.098970 seconds, 95808 images
# Loaded: 0.137505 seconds
#
#  2995: 0.035875, 0.038296 avg loss, 0.001000 rate, 2.114750 seconds, 95840 images
# Loaded: 0.118028 seconds
#  Very small path to the image:
#
#  2996: 0.042835, 0.038750 avg loss, 0.001000 rate, 2.105783 seconds, 95872 images
# Loaded: 0.661548 seconds
#  Very small path to the image:
#
#  2997: 0.029787, 0.037854 avg loss, 0.001000 rate, 2.106488 seconds, 95904 images
# Loaded: 0.419034 seconds
#
#  2998: 0.060907, 0.040159 avg loss, 0.001000 rate, 2.094035 seconds, 95936 images
# Loaded: 0.024168 seconds
#
#  2999: 0.073670, 0.043510 avg loss, 0.001000 rate, 2.171862 seconds, 95968 images
# Loaded: 0.151262 seconds
#
#  3000: 0.020994, 0.041259 avg loss, 0.001000 rate, 2.108478 seconds, 96000 images
# Saving weights to backup/custom-train-yolo_3000.weights
# Saving weights to backup/custom-train-yolo_last.weights
# Resizing
# 416 x 416
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.933032 seconds
#  Very small path to the image:
#
#  3001: 0.036209, 0.040754 avg loss, 0.001000 rate, 2.564658 seconds, 96032 images
# Loaded: 0.063960 seconds
#
#  3002: 0.016256, 0.038304 avg loss, 0.001000 rate, 2.504316 seconds, 96064 images
# Loaded: 0.000040 seconds
#  Very small path to the image:
#
#  3003: 0.023865, 0.036860 avg loss, 0.001000 rate, 2.569843 seconds, 96096 images
# Loaded: 0.037656 seconds
#
#  3004: 0.039282, 0.037102 avg loss, 0.001000 rate, 2.553620 seconds, 96128 images
# Loaded: 0.304114 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3005: 0.045304, 0.037922 avg loss, 0.001000 rate, 2.510090 seconds, 96160 images
# Loaded: 0.464404 seconds
#
#  3006: 0.025349, 0.036665 avg loss, 0.001000 rate, 2.493706 seconds, 96192 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#
#  3007: 0.039930, 0.036992 avg loss, 0.001000 rate, 2.600148 seconds, 96224 images
# Loaded: 0.286097 seconds
#
#  3008: 0.019162, 0.035209 avg loss, 0.001000 rate, 2.508263 seconds, 96256 images
# Loaded: 0.107947 seconds
#
#  3009: 0.032488, 0.034937 avg loss, 0.001000 rate, 2.485086 seconds, 96288 images
# Loaded: 0.611570 seconds
#  Very small path to the image:
#
#  3010: 0.039558, 0.035399 avg loss, 0.001000 rate, 2.483349 seconds, 96320 images
# Resizing
# 480 x 480
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 67.74 MB
#  CUDA allocate done!
# Loaded: 0.148891 seconds
#
#  3011: 0.027032, 0.034562 avg loss, 0.001000 rate, 3.123610 seconds, 96352 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3012: 0.026753, 0.033781 avg loss, 0.001000 rate, 3.159977 seconds, 96384 images
# Loaded: 0.000031 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3013: 0.041121, 0.034515 avg loss, 0.001000 rate, 3.144494 seconds, 96416 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3014: 0.032052, 0.034269 avg loss, 0.001000 rate, 3.157862 seconds, 96448 images
# Loaded: 0.000036 seconds
#
#  3015: 0.020532, 0.032895 avg loss, 0.001000 rate, 3.151849 seconds, 96480 images
# Loaded: 0.000045 seconds
#
#  3016: 0.038661, 0.033472 avg loss, 0.001000 rate, 3.172130 seconds, 96512 images
# Loaded: 0.000034 seconds
#  Very small path to the image:
#
#  3017: 0.030043, 0.033129 avg loss, 0.001000 rate, 3.173091 seconds, 96544 images
# Loaded: 0.000031 seconds
#  Very small path to the image:
#
#  3018: 0.026876, 0.032503 avg loss, 0.001000 rate, 3.168677 seconds, 96576 images
# Loaded: 0.000043 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3019: 0.041455, 0.033399 avg loss, 0.001000 rate, 3.157639 seconds, 96608 images
# Loaded: 0.000040 seconds
#
#  3020: 0.031886, 0.033247 avg loss, 0.001000 rate, 3.156135 seconds, 96640 images
# Resizing
# 480 x 480
#  Very small path to the image:
#  try to allocate additional workspace_size = 67.74 MB
#  CUDA allocate done!
# Loaded: 2.368830 seconds
#  Very small path to the image:
#
#  3021: 0.040931, 0.034016 avg loss, 0.001000 rate, 3.112474 seconds, 96672 images
# Loaded: 0.118218 seconds
#  Very small path to the image:
#
#  3022: 0.023321, 0.032946 avg loss, 0.001000 rate, 3.038694 seconds, 96704 images
# Loaded: 0.000034 seconds
#  Very small path to the image:
#
#  3023: 0.025685, 0.032220 avg loss, 0.001000 rate, 3.153701 seconds, 96736 images
# Loaded: 0.000039 seconds
#
#  3024: 0.046147, 0.033613 avg loss, 0.001000 rate, 3.152941 seconds, 96768 images
# Loaded: 0.000052 seconds
#
#  3025: 0.023765, 0.032628 avg loss, 0.001000 rate, 3.165106 seconds, 96800 images
# Loaded: 0.000034 seconds
#  Very small path to the image:
#
#  3026: 0.018920, 0.031257 avg loss, 0.001000 rate, 3.147519 seconds, 96832 images
# Loaded: 0.000032 seconds
#  Very small path to the image:
#
#  3027: 0.072073, 0.035339 avg loss, 0.001000 rate, 3.170745 seconds, 96864 images
# Loaded: 0.000063 seconds
#  Very small path to the image:
#
#  3028: 0.026368, 0.034442 avg loss, 0.001000 rate, 3.179371 seconds, 96896 images
# Loaded: 0.000042 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3029: 0.022337, 0.033231 avg loss, 0.001000 rate, 3.164451 seconds, 96928 images
# Loaded: 0.000042 seconds
#
#  3030: 0.019463, 0.031854 avg loss, 0.001000 rate, 3.161757 seconds, 96960 images
# Resizing
# 608 x 608
#  Very small path to the image:
#  try to allocate additional workspace_size = 108.69 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3031: 0.061872, 0.034856 avg loss, 0.001000 rate, 4.943726 seconds, 96992 images
# Loaded: 0.000034 seconds
#
#  3032: 0.059529, 0.037323 avg loss, 0.001000 rate, 5.090038 seconds, 97024 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#
#  3033: 0.029014, 0.036493 avg loss, 0.001000 rate, 5.069136 seconds, 97056 images
# Loaded: 0.000032 seconds
#  Very small path to the image:
#
#  3034: 0.033450, 0.036188 avg loss, 0.001000 rate, 5.107816 seconds, 97088 images
# Loaded: 0.000061 seconds
#  Very small path to the image:
#
#  3035: 0.046592, 0.037229 avg loss, 0.001000 rate, 5.088750 seconds, 97120 images
# Loaded: 0.000029 seconds
#
#  3036: 0.046117, 0.038117 avg loss, 0.001000 rate, 5.126023 seconds, 97152 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3037: 0.031050, 0.037411 avg loss, 0.001000 rate, 5.115585 seconds, 97184 images
# Loaded: 0.000031 seconds
#
#  3038: 0.032444, 0.036914 avg loss, 0.001000 rate, 5.077151 seconds, 97216 images
# Loaded: 0.000036 seconds
#
#  3039: 0.035696, 0.036792 avg loss, 0.001000 rate, 5.100716 seconds, 97248 images
# Loaded: 0.000041 seconds
#
#  3040: 0.076873, 0.040800 avg loss, 0.001000 rate, 5.086397 seconds, 97280 images
# Resizing
# 416 x 416
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.334780 seconds
#  Very small path to the image:
#
#  3041: 0.036324, 0.040353 avg loss, 0.001000 rate, 2.572389 seconds, 97312 images
# Loaded: 0.000041 seconds
#  Very small path to the image:
#
#  3042: 0.024644, 0.038782 avg loss, 0.001000 rate, 2.568172 seconds, 97344 images
# Loaded: 0.277910 seconds
#
#  3043: 0.025578, 0.037461 avg loss, 0.001000 rate, 2.471746 seconds, 97376 images
# Loaded: 0.000036 seconds
#
#  3044: 0.047658, 0.038481 avg loss, 0.001000 rate, 2.584294 seconds, 97408 images
# Loaded: 0.121864 seconds
#
#  3045: 0.015241, 0.036157 avg loss, 0.001000 rate, 2.476842 seconds, 97440 images
# Loaded: 0.000035 seconds
#
#  3046: 0.022584, 0.034800 avg loss, 0.001000 rate, 2.569108 seconds, 97472 images
# Loaded: 0.044760 seconds
#
#  3047: 0.030424, 0.034362 avg loss, 0.001000 rate, 2.521947 seconds, 97504 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#
#  3048: 0.027474, 0.033673 avg loss, 0.001000 rate, 2.600795 seconds, 97536 images
# Loaded: 0.032517 seconds
#  Very small path to the image:
#
#  3049: 0.019400, 0.032246 avg loss, 0.001000 rate, 2.544771 seconds, 97568 images
# Loaded: 0.000034 seconds
#
#  3050: 0.019871, 0.031009 avg loss, 0.001000 rate, 2.582889 seconds, 97600 images
# Resizing
# 576 x 576
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 97.55 MB
#  CUDA allocate done!
# Loaded: 0.303122 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3051: 0.035156, 0.031423 avg loss, 0.001000 rate, 4.529506 seconds, 97632 images
# Loaded: 0.000052 seconds
#  Very small path to the image:
#
#  3052: 0.034890, 0.031770 avg loss, 0.001000 rate, 4.647428 seconds, 97664 images
# Loaded: 0.000037 seconds
#
#  3053: 0.031626, 0.031756 avg loss, 0.001000 rate, 4.669069 seconds, 97696 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#
#  3054: 0.042944, 0.032874 avg loss, 0.001000 rate, 4.673305 seconds, 97728 images
# Loaded: 0.000035 seconds
#
#  3055: 0.041149, 0.033702 avg loss, 0.001000 rate, 4.701476 seconds, 97760 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#
#  3056: 0.039691, 0.034301 avg loss, 0.001000 rate, 4.709079 seconds, 97792 images
# Loaded: 0.000053 seconds
#
#  3057: 0.052954, 0.036166 avg loss, 0.001000 rate, 4.694076 seconds, 97824 images
# Loaded: 0.000037 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3058: 0.023063, 0.034856 avg loss, 0.001000 rate, 4.699350 seconds, 97856 images
# Loaded: 0.000036 seconds
#
#  3059: 0.045153, 0.035886 avg loss, 0.001000 rate, 4.680325 seconds, 97888 images
# Loaded: 0.000031 seconds
#
#  3060: 0.029797, 0.035277 avg loss, 0.001000 rate, 4.664607 seconds, 97920 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 77.07 MB
#  CUDA allocate done!
# Loaded: 1.571031 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3061: 0.037193, 0.035468 avg loss, 0.001000 rate, 3.326279 seconds, 97952 images
# Loaded: 0.000038 seconds
#  Very small path to the image:
#
#  3062: 0.020618, 0.033983 avg loss, 0.001000 rate, 3.405737 seconds, 97984 images
# Loaded: 0.000037 seconds
#  Very small path to the image:
#
#  3063: 0.030825, 0.033667 avg loss, 0.001000 rate, 3.397984 seconds, 98016 images
# Loaded: 0.000035 seconds
#
#  3064: 0.029937, 0.033294 avg loss, 0.001000 rate, 3.419426 seconds, 98048 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#
#  3065: 0.032732, 0.033238 avg loss, 0.001000 rate, 3.407932 seconds, 98080 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3066: 0.050044, 0.034919 avg loss, 0.001000 rate, 3.393119 seconds, 98112 images
# Loaded: 0.000040 seconds
#
#  3067: 0.040712, 0.035498 avg loss, 0.001000 rate, 3.395552 seconds, 98144 images
# Loaded: 0.000049 seconds
#  Very small path to the image:
#
#  3068: 0.031120, 0.035060 avg loss, 0.001000 rate, 3.394366 seconds, 98176 images
# Loaded: 0.000035 seconds
#
#  3069: 0.025071, 0.034061 avg loss, 0.001000 rate, 3.393501 seconds, 98208 images
# Loaded: 0.000033 seconds
#
#  3070: 0.038764, 0.034532 avg loss, 0.001000 rate, 3.387142 seconds, 98240 images
# Resizing
# 320 x 320
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.146858 seconds
#  Very small path to the image:
#
#  3071: 0.052067, 0.036285 avg loss, 0.001000 rate, 1.703333 seconds, 98272 images
# Loaded: 0.347327 seconds
#
#  3072: 0.073307, 0.039987 avg loss, 0.001000 rate, 1.621694 seconds, 98304 images
# Loaded: 1.058535 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3073: 0.073776, 0.043366 avg loss, 0.001000 rate, 1.648166 seconds, 98336 images
# Loaded: 0.807938 seconds
#
#  3074: 0.051783, 0.044208 avg loss, 0.001000 rate, 1.632784 seconds, 98368 images
# Loaded: 0.673113 seconds
#  Very small path to the image:
#
#  3075: 0.053890, 0.045176 avg loss, 0.001000 rate, 1.643038 seconds, 98400 images
# Loaded: 1.138175 seconds
#  Very small path to the image:
#
#  3076: 0.085969, 0.049255 avg loss, 0.001000 rate, 1.640855 seconds, 98432 images
# Loaded: 1.102240 seconds
#
#  3077: 0.041581, 0.048488 avg loss, 0.001000 rate, 1.635163 seconds, 98464 images
# Loaded: 0.681516 seconds
#
#  3078: 0.040072, 0.047646 avg loss, 0.001000 rate, 1.654867 seconds, 98496 images
# Loaded: 0.809897 seconds
#
#  3079: 0.101664, 0.053048 avg loss, 0.001000 rate, 1.652292 seconds, 98528 images
# Loaded: 0.981056 seconds
#  Very small path to the image:
#
#  3080: 0.060603, 0.053804 avg loss, 0.001000 rate, 1.642371 seconds, 98560 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.280992 seconds
#  Very small path to the image:
#
#  3081: 0.038952, 0.052318 avg loss, 0.001000 rate, 1.934077 seconds, 98592 images
# Loaded: 0.602640 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3082: 0.052896, 0.052376 avg loss, 0.001000 rate, 1.880650 seconds, 98624 images
# Loaded: 0.933303 seconds
#  Very small path to the image:
#
#  3083: 0.051629, 0.052301 avg loss, 0.001000 rate, 1.871328 seconds, 98656 images
# Loaded: 0.814869 seconds
#  Very small path to the image:
#
#  3084: 0.055712, 0.052643 avg loss, 0.001000 rate, 1.878759 seconds, 98688 images
# Loaded: 0.119305 seconds
#
#  3085: 0.041028, 0.051481 avg loss, 0.001000 rate, 1.881441 seconds, 98720 images
# Loaded: 0.312558 seconds
#
#  3086: 0.037719, 0.050105 avg loss, 0.001000 rate, 1.868803 seconds, 98752 images
# Loaded: 0.815935 seconds
#  Very small path to the image:
#
#  3087: 0.034782, 0.048573 avg loss, 0.001000 rate, 1.872041 seconds, 98784 images
# Loaded: 0.571553 seconds
#  Very small path to the image:
#
#  3088: 0.041614, 0.047877 avg loss, 0.001000 rate, 1.874107 seconds, 98816 images
# Loaded: 1.009780 seconds
#
#  3089: 0.053012, 0.048390 avg loss, 0.001000 rate, 1.898610 seconds, 98848 images
# Loaded: 0.763511 seconds
#
#  3090: 0.050941, 0.048645 avg loss, 0.001000 rate, 1.900548 seconds, 98880 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 67.74 MB
#  CUDA allocate done!
# Loaded: 0.245105 seconds
#
#  3091: 0.045371, 0.048318 avg loss, 0.001000 rate, 3.143995 seconds, 98912 images
# Loaded: 0.000032 seconds
#  Very small path to the image:
#
#  3092: 0.021588, 0.045645 avg loss, 0.001000 rate, 3.193921 seconds, 98944 images
# Loaded: 0.000039 seconds
#
#  3093: 0.050213, 0.046102 avg loss, 0.001000 rate, 3.181808 seconds, 98976 images
# Loaded: 0.000045 seconds
#
#  3094: 0.029412, 0.044433 avg loss, 0.001000 rate, 3.162220 seconds, 99008 images
# Loaded: 0.000037 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3095: 0.038210, 0.043811 avg loss, 0.001000 rate, 3.167595 seconds, 99040 images
# Loaded: 0.000050 seconds
#  Very small path to the image:
#
#  3096: 0.022328, 0.041662 avg loss, 0.001000 rate, 3.168828 seconds, 99072 images
# Loaded: 0.000053 seconds
#  Very small path to the image:
#
#  3097: 0.029485, 0.040445 avg loss, 0.001000 rate, 3.158255 seconds, 99104 images
# Loaded: 0.069347 seconds
#
#  3098: 0.024744, 0.038875 avg loss, 0.001000 rate, 3.076628 seconds, 99136 images
# Loaded: 0.000036 seconds
#
#  3099: 0.037731, 0.038760 avg loss, 0.001000 rate, 3.156202 seconds, 99168 images
# Loaded: 0.000030 seconds
#  Very small path to the image:
#
#  3100: 0.040812, 0.038965 avg loss, 0.001000 rate, 3.149524 seconds, 99200 images
# Saving weights to backup/custom-train-yolo_last.weights
# Resizing
# 352 x 352
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 2.095838 seconds
#
#  3101: 0.045478, 0.039617 avg loss, 0.001000 rate, 1.954715 seconds, 99232 images
# Loaded: 0.366920 seconds
#  Very small path to the image:
#
#  3102: 0.053723, 0.041027 avg loss, 0.001000 rate, 1.868876 seconds, 99264 images
# Loaded: 0.334500 seconds
#  Very small path to the image:
#
#  3103: 0.023736, 0.039298 avg loss, 0.001000 rate, 1.873320 seconds, 99296 images
# Loaded: 0.367532 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3104: 0.027090, 0.038077 avg loss, 0.001000 rate, 1.870770 seconds, 99328 images
# Loaded: 0.263308 seconds
#
#  3105: 0.037455, 0.038015 avg loss, 0.001000 rate, 1.859996 seconds, 99360 images
# Loaded: 0.244810 seconds
#
#  3106: 0.080124, 0.042226 avg loss, 0.001000 rate, 1.882183 seconds, 99392 images
# Loaded: 0.370846 seconds
#  Very small path to the image:
#
#  3107: 0.045313, 0.042535 avg loss, 0.001000 rate, 1.878002 seconds, 99424 images
# Loaded: 0.386058 seconds
#
#  3108: 0.061878, 0.044469 avg loss, 0.001000 rate, 1.857179 seconds, 99456 images
# Loaded: 0.449589 seconds
#  Very small path to the image:
#
#  3109: 0.053723, 0.045394 avg loss, 0.001000 rate, 1.865896 seconds, 99488 images
# Loaded: 0.056479 seconds
#
#  3110: 0.046858, 0.045541 avg loss, 0.001000 rate, 1.895568 seconds, 99520 images
# Resizing
# 320 x 320
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.705532 seconds
#
#  3111: 0.100189, 0.051006 avg loss, 0.001000 rate, 1.759784 seconds, 99552 images
# Loaded: 0.523006 seconds
#  Very small path to the image:
#
#  3112: 0.051683, 0.051073 avg loss, 0.001000 rate, 1.660834 seconds, 99584 images
# Loaded: 0.674726 seconds
#
#  3113: 0.037218, 0.049688 avg loss, 0.001000 rate, 1.655899 seconds, 99616 images
# Loaded: 0.931093 seconds
#
#  3114: 0.034381, 0.048157 avg loss, 0.001000 rate, 1.640409 seconds, 99648 images
# Loaded: 0.521920 seconds
#  Very small path to the image:
#
#  3115: 0.058612, 0.049203 avg loss, 0.001000 rate, 1.631916 seconds, 99680 images
# Loaded: 0.561586 seconds
#  Very small path to the image:
#
#  3116: 0.024644, 0.046747 avg loss, 0.001000 rate, 1.654218 seconds, 99712 images
# Loaded: 0.757344 seconds
#
#  3117: 0.064838, 0.048556 avg loss, 0.001000 rate, 1.661502 seconds, 99744 images
# Loaded: 0.245021 seconds
#
#  3118: 0.051263, 0.048827 avg loss, 0.001000 rate, 1.643315 seconds, 99776 images
# Loaded: 0.763847 seconds
#  Very small path to the image:
#
#  3119: 0.025415, 0.046485 avg loss, 0.001000 rate, 1.640392 seconds, 99808 images
# Loaded: 0.487774 seconds
#
#  3120: 0.044286, 0.046265 avg loss, 0.001000 rate, 1.655299 seconds, 99840 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.492607 seconds
#  Very small path to the image:
#
#  3121: 0.029434, 0.044582 avg loss, 0.001000 rate, 2.600276 seconds, 99872 images
# Loaded: 0.000034 seconds
#
#  3122: 0.030528, 0.043177 avg loss, 0.001000 rate, 2.579320 seconds, 99904 images
# Loaded: 0.000042 seconds
#
#  3123: 0.040079, 0.042867 avg loss, 0.001000 rate, 2.589791 seconds, 99936 images
# Loaded: 0.000039 seconds
#  Very small path to the image:
#
#  3124: 0.039634, 0.042544 avg loss, 0.001000 rate, 2.586735 seconds, 99968 images
# Loaded: 0.000055 seconds
#
#  3125: 0.040463, 0.042336 avg loss, 0.001000 rate, 2.590331 seconds, 100000 images
# Loaded: 0.000037 seconds
#
#  3126: 0.032701, 0.041372 avg loss, 0.001000 rate, 2.587490 seconds, 100032 images
# Loaded: 0.000030 seconds
#  Very small path to the image:
#
#  3127: 0.019724, 0.039207 avg loss, 0.001000 rate, 2.588031 seconds, 100064 images
# Loaded: 0.291486 seconds
#
#  3128: 0.029307, 0.038217 avg loss, 0.001000 rate, 2.510794 seconds, 100096 images
# Loaded: 0.261202 seconds
#  Very small path to the image:
#
#  3129: 0.024515, 0.036847 avg loss, 0.001000 rate, 2.496348 seconds, 100128 images
# Loaded: 0.082435 seconds
#
#  3130: 0.043127, 0.037475 avg loss, 0.001000 rate, 2.507790 seconds, 100160 images
# Resizing
# 416 x 416
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.954028 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3131: 0.023951, 0.036123 avg loss, 0.001000 rate, 2.564038 seconds, 100192 images
# Loaded: 0.000029 seconds
#
#  3132: 0.029641, 0.035475 avg loss, 0.001000 rate, 2.605160 seconds, 100224 images
# Loaded: 0.079320 seconds
#
#  3133: 0.020963, 0.034023 avg loss, 0.001000 rate, 2.532779 seconds, 100256 images
# Loaded: 0.312055 seconds
#
#  3134: 0.032976, 0.033919 avg loss, 0.001000 rate, 2.490823 seconds, 100288 images
# Loaded: 0.000032 seconds
#
#  3135: 0.020622, 0.032589 avg loss, 0.001000 rate, 2.575359 seconds, 100320 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3136: 0.026957, 0.032026 avg loss, 0.001000 rate, 2.586285 seconds, 100352 images
# Loaded: 0.295794 seconds
#
#  3137: 0.030937, 0.031917 avg loss, 0.001000 rate, 2.474903 seconds, 100384 images
# Loaded: 0.478482 seconds
#
#  3138: 0.023412, 0.031066 avg loss, 0.001000 rate, 2.476410 seconds, 100416 images
# Loaded: 0.000029 seconds
#
#  3139: 0.030640, 0.031024 avg loss, 0.001000 rate, 2.576977 seconds, 100448 images
# Loaded: 0.353093 seconds
#
#  3140: 0.020790, 0.030000 avg loss, 0.001000 rate, 2.476584 seconds, 100480 images
# Resizing
# ...
# Loaded: 0.175629 seconds
#  Very small path to the image:
#
#  3894: 0.030208, 0.021339 avg loss, 0.000010 rate, 2.742087 seconds, 124608 images
# Loaded: 0.272159 seconds
#
#  3895: 0.012680, 0.020473 avg loss, 0.000010 rate, 2.746465 seconds, 124640 images
# Loaded: 0.000034 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3896: 0.011988, 0.019624 avg loss, 0.000010 rate, 2.846070 seconds, 124672 images
# Loaded: 0.037286 seconds
#
#  3897: 0.008151, 0.018477 avg loss, 0.000010 rate, 2.785919 seconds, 124704 images
# Loaded: 0.000029 seconds
#  Very small path to the image:
#
#  3898: 0.012933, 0.017923 avg loss, 0.000010 rate, 2.833089 seconds, 124736 images
# Loaded: 0.000038 seconds
#
#  3899: 0.009098, 0.017040 avg loss, 0.000010 rate, 2.868861 seconds, 124768 images
# Loaded: 0.023697 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3900: 0.012923, 0.016628 avg loss, 0.000010 rate, 2.812714 seconds, 124800 images
# Saving weights to backup/custom-train-yolo_last.weights
# Resizing
# 352 x 352
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.683972 seconds
#  Very small path to the image:
#
#  3901: 0.038111, 0.018777 avg loss, 0.000010 rate, 1.959580 seconds, 124832 images
# Loaded: 0.662836 seconds
#  Very small path to the image:
#
#  3902: 0.050544, 0.021953 avg loss, 0.000010 rate, 1.860922 seconds, 124864 images
# Loaded: 0.636260 seconds
#  Very small path to the image:
#
#  3903: 0.018809, 0.021639 avg loss, 0.000010 rate, 1.873988 seconds, 124896 images
# Loaded: 0.436014 seconds
#  Very small path to the image:
#
#  3904: 0.016211, 0.021096 avg loss, 0.000010 rate, 1.871150 seconds, 124928 images
# Loaded: 0.715524 seconds
#  Very small path to the image:
#
#  3905: 0.029001, 0.021887 avg loss, 0.000010 rate, 1.858753 seconds, 124960 images
# Loaded: 0.221926 seconds
#
#  3906: 0.014008, 0.021099 avg loss, 0.000010 rate, 1.863445 seconds, 124992 images
# Loaded: 0.145691 seconds
#
#  3907: 0.016353, 0.020624 avg loss, 0.000010 rate, 1.886603 seconds, 125024 images
# Loaded: 0.986185 seconds
#
#  3908: 0.024920, 0.021054 avg loss, 0.000010 rate, 1.878777 seconds, 125056 images
# Loaded: 0.748041 seconds
#
#  3909: 0.017128, 0.020661 avg loss, 0.000010 rate, 1.875137 seconds, 125088 images
# Loaded: 0.284565 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3910: 0.016659, 0.020261 avg loss, 0.000010 rate, 1.877021 seconds, 125120 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.585385 seconds
#
#  3911: 0.009396, 0.019175 avg loss, 0.000010 rate, 2.203930 seconds, 125152 images
# Loaded: 0.387009 seconds
#  Very small path to the image:
#
#  3912: 0.020459, 0.019303 avg loss, 0.000010 rate, 2.097755 seconds, 125184 images
# Loaded: 0.422174 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3913: 0.027310, 0.020104 avg loss, 0.000010 rate, 2.094717 seconds, 125216 images
# Loaded: 0.179493 seconds
#
#  3914: 0.016543, 0.019748 avg loss, 0.000010 rate, 2.097142 seconds, 125248 images
# Loaded: 0.614595 seconds
#
#  3915: 0.028652, 0.020638 avg loss, 0.000010 rate, 2.108565 seconds, 125280 images
# Loaded: 0.446728 seconds
#
#  3916: 0.011768, 0.019751 avg loss, 0.000010 rate, 2.101712 seconds, 125312 images
# Loaded: 0.178104 seconds
#
#  3917: 0.041845, 0.021960 avg loss, 0.000010 rate, 2.134685 seconds, 125344 images
# Loaded: 0.218691 seconds
#
#  3918: 0.025075, 0.022272 avg loss, 0.000010 rate, 2.120137 seconds, 125376 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#
#  3919: 0.021863, 0.022231 avg loss, 0.000010 rate, 2.184519 seconds, 125408 images
# Loaded: 0.163614 seconds
#  Very small path to the image:
#
#  3920: 0.017321, 0.021740 avg loss, 0.000010 rate, 2.113183 seconds, 125440 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 67.74 MB
#  CUDA allocate done!
# Loaded: 0.000047 seconds
#  Very small path to the image:
#
#  3921: 0.018184, 0.021384 avg loss, 0.000010 rate, 3.105380 seconds, 125472 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3922: 0.017290, 0.020975 avg loss, 0.000010 rate, 3.169511 seconds, 125504 images
# Loaded: 0.000031 seconds
#
#  3923: 0.014274, 0.020305 avg loss, 0.000010 rate, 3.176546 seconds, 125536 images
# Loaded: 0.000036 seconds
#  Very small path to the image:
#
#  3924: 0.014406, 0.019715 avg loss, 0.000010 rate, 3.190638 seconds, 125568 images
# Loaded: 0.000040 seconds
#  Very small path to the image:
#
#  3925: 0.023809, 0.020124 avg loss, 0.000010 rate, 3.174591 seconds, 125600 images
# Loaded: 0.000039 seconds
#  Very small path to the image:
#
#  3926: 0.013759, 0.019488 avg loss, 0.000010 rate, 3.160585 seconds, 125632 images
# Loaded: 0.000033 seconds
#
#  3927: 0.020235, 0.019563 avg loss, 0.000010 rate, 3.186598 seconds, 125664 images
# Loaded: 0.001952 seconds
#  Very small path to the image:
#
#  3928: 0.028916, 0.020498 avg loss, 0.000010 rate, 3.161266 seconds, 125696 images
# Loaded: 0.000045 seconds
#
#  3929: 0.015223, 0.019970 avg loss, 0.000010 rate, 3.158417 seconds, 125728 images
# Loaded: 0.000078 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3930: 0.019180, 0.019891 avg loss, 0.000010 rate, 3.181886 seconds, 125760 images
# Resizing
# 576 x 576
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 97.55 MB
#  CUDA allocate done!
# Loaded: 0.000052 seconds
#
#  3931: 0.014282, 0.019330 avg loss, 0.000010 rate, 4.549667 seconds, 125792 images
# Loaded: 0.000030 seconds
#
#  3932: 0.030302, 0.020428 avg loss, 0.000010 rate, 4.649405 seconds, 125824 images
# Loaded: 0.000035 seconds
#
#  3933: 0.018723, 0.020257 avg loss, 0.000010 rate, 4.658137 seconds, 125856 images
# Loaded: 0.000032 seconds
#  Very small path to the image:
#
#  3934: 0.017650, 0.019996 avg loss, 0.000010 rate, 4.657322 seconds, 125888 images
# Loaded: 0.000075 seconds
#  Very small path to the image:
#
#  3935: 0.018505, 0.019847 avg loss, 0.000010 rate, 4.646547 seconds, 125920 images
# Loaded: 0.000065 seconds
#
#  3936: 0.012226, 0.019085 avg loss, 0.000010 rate, 4.675502 seconds, 125952 images
# Loaded: 0.000031 seconds
#
#  3937: 0.027579, 0.019935 avg loss, 0.000010 rate, 4.670388 seconds, 125984 images
# Loaded: 0.000049 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3938: 0.025854, 0.020527 avg loss, 0.000010 rate, 4.667263 seconds, 126016 images
# Loaded: 0.000032 seconds
#
#  3939: 0.018137, 0.020288 avg loss, 0.000010 rate, 4.680277 seconds, 126048 images
# Loaded: 0.000033 seconds
#
#  3940: 0.018802, 0.020139 avg loss, 0.000010 rate, 4.678365 seconds, 126080 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 97.55 MB
#  CUDA allocate done!
# Loaded: 1.634049 seconds
#  Very small path to the image:
#
#  3941: 0.028175, 0.020943 avg loss, 0.000010 rate, 4.604006 seconds, 126112 images
# Loaded: 0.000029 seconds
#
#  3942: 0.037226, 0.022571 avg loss, 0.000010 rate, 4.647136 seconds, 126144 images
# Loaded: 0.000036 seconds
#
#  3943: 0.013438, 0.021658 avg loss, 0.000010 rate, 4.663105 seconds, 126176 images
# Loaded: 0.000030 seconds
#
#  3944: 0.022931, 0.021785 avg loss, 0.000010 rate, 4.655326 seconds, 126208 images
# Loaded: 0.000043 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3945: 0.031357, 0.022742 avg loss, 0.000010 rate, 4.675783 seconds, 126240 images
# Loaded: 0.000052 seconds
#
#  3946: 0.018924, 0.022360 avg loss, 0.000010 rate, 4.659206 seconds, 126272 images
# Loaded: 0.000039 seconds
#
#  3947: 0.024479, 0.022572 avg loss, 0.000010 rate, 4.669611 seconds, 126304 images
# Loaded: 0.000042 seconds
#  Very small path to the image:
#
#  3948: 0.015274, 0.021842 avg loss, 0.000010 rate, 4.663825 seconds, 126336 images
# Loaded: 0.000033 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3949: 0.013737, 0.021032 avg loss, 0.000010 rate, 4.688109 seconds, 126368 images
# Loaded: 0.000036 seconds
#
#  3950: 0.029525, 0.021881 avg loss, 0.000010 rate, 4.661091 seconds, 126400 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.079614 seconds
#  Very small path to the image:
#
#  3951: 0.019885, 0.021682 avg loss, 0.000010 rate, 2.204181 seconds, 126432 images
# Loaded: 0.509631 seconds
#
#  3952: 0.027748, 0.022288 avg loss, 0.000010 rate, 2.114220 seconds, 126464 images
# Loaded: 0.038693 seconds
#  Very small path to the image:
#
#  3953: 0.013853, 0.021445 avg loss, 0.000010 rate, 2.149714 seconds, 126496 images
# Loaded: 0.481400 seconds
#
#  3954: 0.020670, 0.021367 avg loss, 0.000010 rate, 2.112036 seconds, 126528 images
# Loaded: 0.420868 seconds
#
#  3955: 0.015455, 0.020776 avg loss, 0.000010 rate, 2.103402 seconds, 126560 images
# Loaded: 0.689934 seconds
#
#  3956: 0.010965, 0.019795 avg loss, 0.000010 rate, 2.111783 seconds, 126592 images
# Loaded: 0.547642 seconds
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#
#  3957: 0.011590, 0.018974 avg loss, 0.000010 rate, 2.115787 seconds, 126624 images
# Loaded: 0.637225 seconds
#  Very small path to the image:
#
#  3958: 0.007171, 0.017794 avg loss, 0.000010 rate, 2.099394 seconds, 126656 images
# Loaded: 0.266661 seconds
#
#  3959: 0.013888, 0.017404 avg loss, 0.000010 rate, 2.111395 seconds, 126688 images
# Loaded: 0.612674 seconds
#
#  3960: 0.010859, 0.016749 avg loss, 0.000010 rate, 2.108684 seconds, 126720 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.894552 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3961: 0.017940, 0.016868 avg loss, 0.000010 rate, 2.164261 seconds, 126752 images
# Loaded: 0.582929 seconds
#
#  3962: 0.026146, 0.017796 avg loss, 0.000010 rate, 2.105491 seconds, 126784 images
# Loaded: 0.543568 seconds
#  Very small path to the image:
#
#  3963: 0.031971, 0.019213 avg loss, 0.000010 rate, 2.114209 seconds, 126816 images
# Loaded: 0.752034 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3964: 0.019792, 0.019271 avg loss, 0.000010 rate, 2.111875 seconds, 126848 images
# Loaded: 0.500321 seconds
#
#  3965: 0.015928, 0.018937 avg loss, 0.000010 rate, 2.134194 seconds, 126880 images
# Loaded: 0.376793 seconds
#  Very small path to the image:
#
#  3966: 0.016443, 0.018688 avg loss, 0.000010 rate, 2.113473 seconds, 126912 images
# Loaded: 0.583580 seconds
#
#  3967: 0.015043, 0.018323 avg loss, 0.000010 rate, 2.117108 seconds, 126944 images
# Loaded: 0.331973 seconds
#
#  3968: 0.024890, 0.018980 avg loss, 0.000010 rate, 2.111717 seconds, 126976 images
# Loaded: 0.554847 seconds
#
#  3969: 0.014659, 0.018548 avg loss, 0.000010 rate, 2.111027 seconds, 127008 images
# Loaded: 0.519495 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3970: 0.023868, 0.019080 avg loss, 0.000010 rate, 2.127976 seconds, 127040 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.964932 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3971: 0.011535, 0.018325 avg loss, 0.000010 rate, 2.180555 seconds, 127072 images
# Loaded: 0.189534 seconds
#  Very small path to the image:
#
#  3972: 0.018405, 0.018333 avg loss, 0.000010 rate, 2.118895 seconds, 127104 images
# Loaded: 0.290084 seconds
#
#  3973: 0.022383, 0.018738 avg loss, 0.000010 rate, 2.107903 seconds, 127136 images
# Loaded: 0.701146 seconds
#
#  3974: 0.034493, 0.020314 avg loss, 0.000010 rate, 2.115174 seconds, 127168 images
# Loaded: 0.290056 seconds
#  Very small path to the image:
#
#  3975: 0.016584, 0.019941 avg loss, 0.000010 rate, 2.108054 seconds, 127200 images
# Loaded: 0.505019 seconds
#
#  3976: 0.021582, 0.020105 avg loss, 0.000010 rate, 2.102274 seconds, 127232 images
# Loaded: 0.293409 seconds
#  Very small path to the image:
#
#  3977: 0.022552, 0.020350 avg loss, 0.000010 rate, 2.123492 seconds, 127264 images
# Loaded: 0.695788 seconds
#  Very small path to the image:
#
#  3978: 0.018219, 0.020137 avg loss, 0.000010 rate, 2.127801 seconds, 127296 images
# Loaded: 0.305681 seconds
#  Very small path to the image:
#
#  3979: 0.020203, 0.020143 avg loss, 0.000010 rate, 2.114982 seconds, 127328 images
# Loaded: 0.106248 seconds
#  Very small path to the image:
#
#  3980: 0.016280, 0.019757 avg loss, 0.000010 rate, 2.105512 seconds, 127360 images
# Resizing
# 608 x 608
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  Very small path to the image:
#  try to allocate additional workspace_size = 108.69 MB
#  CUDA allocate done!
# Loaded: 0.114969 seconds
#
#  3981: 0.046042, 0.022385 avg loss, 0.000010 rate, 4.959538 seconds, 127392 images
# Loaded: 0.000036 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3982: 0.026620, 0.022809 avg loss, 0.000010 rate, 5.083519 seconds, 127424 images
# Loaded: 0.000067 seconds
#  Very small path to the image:
#
#  3983: 0.018542, 0.022382 avg loss, 0.000010 rate, 5.078365 seconds, 127456 images
# Loaded: 0.000039 seconds
#
#  3984: 0.017359, 0.021880 avg loss, 0.000010 rate, 5.090322 seconds, 127488 images
# Loaded: 0.000048 seconds
#
#  3985: 0.029355, 0.022627 avg loss, 0.000010 rate, 5.082482 seconds, 127520 images
# Loaded: 0.000035 seconds
#  Very small path to the image:
#
#  3986: 0.024653, 0.022830 avg loss, 0.000010 rate, 5.106402 seconds, 127552 images
# Loaded: 0.000040 seconds
#  Very small path to the image:
#
#  3987: 0.022996, 0.022846 avg loss, 0.000010 rate, 5.096495 seconds, 127584 images
# Loaded: 0.000047 seconds
#
#  3988: 0.021712, 0.022733 avg loss, 0.000010 rate, 5.101525 seconds, 127616 images
# Loaded: 0.000043 seconds
#
#  3989: 0.020816, 0.022541 avg loss, 0.000010 rate, 5.064010 seconds, 127648 images
# Loaded: 0.000056 seconds
#  Very small path to the image:
#
#  3990: 0.022837, 0.022571 avg loss, 0.000010 rate, 5.087482 seconds, 127680 images
# Resizing
# 384 x 384
#  Very small path to the image:
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.106847 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3991: 0.014858, 0.021800 avg loss, 0.000010 rate, 2.193901 seconds, 127712 images
# Loaded: 0.316750 seconds
#  Very small path to the image:
#
#  3992: 0.018033, 0.021423 avg loss, 0.000010 rate, 2.096212 seconds, 127744 images
# Loaded: 0.196565 seconds
#
#  3993: 0.008394, 0.020120 avg loss, 0.000010 rate, 2.107406 seconds, 127776 images
# Loaded: 0.429870 seconds
#  Very small path to the image:
#
#  3994: 0.056436, 0.023752 avg loss, 0.000010 rate, 2.099532 seconds, 127808 images
# Loaded: 0.191479 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3995: 0.019904, 0.023367 avg loss, 0.000010 rate, 2.097756 seconds, 127840 images
# Loaded: 0.711946 seconds
#
#  3996: 0.020608, 0.023091 avg loss, 0.000010 rate, 2.107826 seconds, 127872 images
# Loaded: 0.477816 seconds
#  Very small path to the image:
#
#  3997: 0.050412, 0.025823 avg loss, 0.000010 rate, 2.106582 seconds, 127904 images
# Loaded: 0.213905 seconds
#
#  3998: 0.013874, 0.024628 avg loss, 0.000010 rate, 2.118474 seconds, 127936 images
# Loaded: 0.882246 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  3999: 0.022917, 0.024457 avg loss, 0.000010 rate, 2.108363 seconds, 127968 images
# Loaded: 0.350340 seconds
#  Very small path to the image:
#
#  4000: 0.012124, 0.023224 avg loss, 0.000010 rate, 2.108912 seconds, 128000 images
# Saving weights to backup/custom-train-yolo_4000.weights
# Saving weights to backup/custom-train-yolo_last.weights
# Saving weights to backup/custom-train-yolo_final.weights

# %% [markdown]
# ASD

# %%
# !cp -r '/content/darknet/backup' '/content/drive/MyDrive/ColabNotebooks/MASK'
